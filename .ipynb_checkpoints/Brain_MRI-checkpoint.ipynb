# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 # good for separating RGB properties of an image. 
import glob
# Out:
# C:\Users\Rudol\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Rudol\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\Rudol\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # Reading images

# %%
from PIL import Image

image = Image.open('./dataset/Mild_Demented/mild.jpg')
plt.imshow(image)
plt.colorbar()

# %%
data_path = './dataset/'
demented_type = ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented'] #should leard how to extract this with code


for folder in demented_type:
    file_name = glob.glob(data_path + folder + '*.jpg')

# %%
data_path = './dataset/'

mild = [] 
very_mild = []
healthy = [] 
moderate = []

for i in glob.glob(data_path + 'Mild_Demented' + '/*.jpg'):
    image = cv2.imread(i)
    image = cv2.resize(image, (128, 128))
    b, g, r = cv2.split(image)
    image = cv2.merge([r, g, b])
    mild.append(image)

for i in glob.glob(data_path + 'Very_Mild_Demented' + '/*.jpg'):
    image = cv2.imread(i)
    image = cv2.resize(image, (128, 128))
    b, g, r = cv2.split(image)
    image = cv2.merge([r, g, b])
    very_mild.append(image)

for i in glob.glob(data_path + 'Non_Demented' + '/*.jpg'):
    image = cv2.imread(i)
    image = cv2.resize(image, (128, 128))
    b, g, r = cv2.split(image)
    image = cv2.merge([r, g, b])
    healthy.append(image)

for i in glob.glob(data_path + 'Moderate_Demented' + '/*.jpg'):
    image = cv2.imread(i)
    image = cv2.resize(image, (128, 128))
    b, g, r = cv2.split(image)
    image = cv2.merge([r, g, b])
    moderate.append(image)

# Print the number of images in each category
print(f"Number of images in Mild Demented: {len(mild)}")
print(f"Number of images in Very Mild Demented: {len(very_mild)}")
print(f"Number of images in Non Demented: {len(healthy)}")
print(f"Number of images in Moderate Demented: {len(moderate)}")
# Out:
# Number of images in Mild Demented: 896
# Number of images in Very Mild Demented: 2240
# Number of images in Non Demented: 3200
# Number of images in Moderate Demented: 64

# %%
mild = np.array(mild)

very_mild = np.array(very_mild)

moderate = np.array(moderate)

healthy = np.array(healthy)

# %%
all_types = np.concatenate((mild, very_mild, moderate, healthy))

# %%
all_types.shape # all images combined into one dimension. the first dimension is the sum of all the demented types
# Out:
# (6400, 128, 128, 3)

# %%
plt.imshow(very_mild[0])

# %%
def plot_random(mild, very_mild, moderate, healthy, num= 3):
    mild_images = mild[np.random.choice(mild.shape[0], num, replace = False)]
    very_mild_images = very_mild[np.random.choice(very_mild.shape[0], num, replace = False)]
    moderate_images = moderate[np.random.choice(moderate.shape[0], num, replace = False)]
    healthy_images = healthy[np.random.choice(healthy.shape[0], num, replace = False)]
    
    plt.figure(figsize = (16, 9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('healthy')
        plt.imshow(healthy_images[i])
    
    plt.figure(figsize = (16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('very_mild')
        plt.imshow(very_mild[i])
        
    plt.figure(figsize = (16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('mild')
        plt.imshow(mild_images[i])
        
    plt.figure(figsize= (16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('moderate')
        plt.imshow(moderate_images[i])

# %%
plot_random(mild, very_mild, moderate, healthy)

# %% [markdown]
# # Data prep

# %% [markdown]
# normalisation, flattening, 1D labels.

# %%
mild.shape
# Out:
# (896, 128, 128, 3)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt



# Reshape the image data to a 2D array where each row represents a flattened image
n_samples = mild.shape[0]
flattened_images = mild.reshape(n_samples, -1)

# Create a StandardScaler instance for normalisation
# scaler = StandardScaler()

# Fit the scaler on the flattened image data and transform. Using the scaler function does not work as 
# there are possible outliers. This is explored further on.
# normalized_flattened_images = scaler.fit_transform(flattened_images)
# Manual normalisation works without the scaler.
normalized_flattened_images = (flattened_images - np.min(flattened_images)) / (np.max(flattened_images) - np.min(flattened_images))

# Calculate mean and standard deviation of normalized data
mean_normalized = np.mean(normalized_flattened_images)
std_normalized = np.std(normalized_flattened_images)

print("Mean of normalized data:", mean_normalized)
print("Standard deviation of normalized data:", std_normalized)

# Visualize the distribution of flattened pixel values before and after normalization
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(flattened_images[0], bins=50, color='blue', alpha=0.7, label='Original')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.title('Distribution of Pixel Values (Original)')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(normalized_flattened_images[0], bins=50, color='green', alpha=0.7, label='Normalized')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.title('Distribution of Pixel Values (Normalized)')
plt.legend()

plt.tight_layout()
plt.show()

# Visualize a few original and normalized images side by side
num_images_to_visualize = 5

plt.figure(figsize=(10, 4))
for i in range(num_images_to_visualize):
    plt.subplot(2, num_images_to_visualize, i + 1)
    plt.imshow(mild[i])
    plt.axis('off')
    plt.title("Original")

    # Reshape the flattened image back to its original dimensions (128x128x3 in this example)
    reshaped_image = normalized_flattened_images[i].reshape(128, 128, 3)
    
    plt.subplot(2, num_images_to_visualize, num_images_to_visualize + i + 1)
    plt.imshow(reshaped_image)
    plt.axis('off')
    plt.title("Normalized")
    
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rudol\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Mean of normalized data: 0.2615434088292919
# Standard deviation of normalized data: 0.31419590740073766

# %% [markdown]
# After normalising, some things to take note of what has changed visually:
#
# **Brightness and Contrast:** Normalization could affect the overall brightness and contrast of the images. If the original images had a wide range of pixel values, normalization might bring pixel values closer together, potentially reducing the contrast and making the images appear slightly darker.
#
# **Color Balance:** If the images are in color (RGB format), normalization could potentially impact the color balance by affecting the values of the red, green, and blue channels. However, this effect is usually subtle and might not be easily noticeable.
#
# **Noise:** In some cases, normalization might reduce the impact of noise, making the images appear smoother. This is because normalization can reduce the range of pixel values, potentially mitigating the influence of outliers.
#
# **Visual Impact:** While the above changes might occur, the overall visual impact of normalization is often minimal. The most significant benefits are usually observed during training and optimization processes when the model relies on consistent and standardized input data.

# %% [markdown]
# ## Exploring outliers

# %%
import numpy as np

# Assuming 'mild' is a NumPy array of shape (num_images, height, width, channels)
# Flatten the images to a 2D array where each row represents a flattened image
n_samples, height, width, channels = mild.shape
flattened_images = mild.reshape(n_samples, -1)

# Calculate the median and IQR for each pixel
median_values = np.median(flattened_images, axis=0)
q1 = np.percentile(flattened_images, 25, axis=0)
q3 = np.percentile(flattened_images, 75, axis=0)
iqr = q3 - q1

# Define a threshold for outlier detection (e.g., 1.5 times IQR)
threshold = 1.5

# Identify outliers based on the threshold
outliers = np.abs(flattened_images - median_values) > threshold * iqr

# Count the number of outliers for each pixel
num_outliers_per_pixel = np.sum(outliers, axis=0)

# Define a threshold for the number of outliers (e.g., consider pixels with more than 100 outliers as outliers)
outlier_threshold = 100

# Create a mask indicating outlier pixels
outlier_mask = num_outliers_per_pixel > outlier_threshold

# Reshape the outlier mask back to the original image dimensions
outlier_mask = outlier_mask.reshape(height, width, channels)

# Display or process the images with identified outliers

# %%
mild.shape
# Out:
# (896, 128, 128, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'mild' is a NumPy array of shape (num_images, height, width, channels)
# Assuming 'outlier_mask' is the binary mask indicating outlier pixels

# Identify outlier images based on the presence of outlier pixels
outlier_images = np.any(outlier_mask, axis=(1, 2))

# Display the values of the outlier images
for i, is_outlier in enumerate(outlier_images):
    if is_outlier:
        outlier_image = mild[i]

# Optionally, you can also display the outlier images using matplotlib
# For example, to display the first outlier image:
outlier_image_indices = np.where(outlier_images)[0]
if len(outlier_image_indices) > 0:
    first_outlier_index = outlier_image_indices[0]
    plt.imshow(mild[first_outlier_index])
    plt.axis('off')
    plt.title("Outlier Image")
    plt.show()

# %%
len(outlier_image_indices)
# Out:
# 112

# %% [markdown]
# Visually comparing outlier and non-outlier images

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'mild' is a NumPy array of shape (num_images, height, width, channels)
# Assuming 'outlier_mask' is the binary mask indicating outlier pixels

# Identify outlier images based on the presence of outlier pixels
outlier_images = np.any(outlier_mask, axis=(1, 2))

# Select a few outlier images and non-outlier images for comparison
num_images_to_compare = 5
outlier_indices = np.where(outlier_images)[0][:num_images_to_compare]
non_outlier_indices = np.where(~outlier_images)[0][:num_images_to_compare]

# Create subplots to display images
plt.figure(figsize=(12, 6))

# Display outlier images
for i, outlier_index in enumerate(outlier_indices):
    plt.subplot(2, num_images_to_compare, i + 1)
    plt.imshow(mild[outlier_index])
    plt.axis('off')
    plt.title(f"Outlier {outlier_index}")

# Display non-outlier images
for i, non_outlier_index in enumerate(non_outlier_indices):
    plt.subplot(2, num_images_to_compare, num_images_to_compare + i + 1)
    plt.imshow(mild[non_outlier_index])
    plt.axis('off')
    plt.title(f"Non-Outlier {non_outlier_index}")

plt.tight_layout()
plt.show()

# %% [markdown]
# The outliers look visually similar to the non-outlier images. More than 10% of time images are outliers (112/896), this is a quite significant number of the images. It would be worthwhile to perform ML with and without the outliers.
#
# Some statistical analysis of the outliers:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'mild' is a NumPy array of shape (num_images, height, width, channels)
# Assuming 'outlier_mask' is the binary mask indicating outlier pixels

# Identify outlier images based on the presence of outlier pixels
outlier_images = np.any(outlier_mask, axis=(1, 2))

# Select a few outlier images and non-outlier images for analysis
num_images_to_analyze = 10  # Adjust as needed
outlier_indices = np.where(outlier_images)[0][:num_images_to_analyze]
non_outlier_indices = np.where(~outlier_images)[0][:num_images_to_analyze]

# Calculate statistics for each group (outliers and non-outliers)
outlier_stats = {
    'Mean': [],
    'Std Dev': [],
    'Min': [],
    'Max': [],
}
non_outlier_stats = {
    'Mean': [],
    'Std Dev': [],
    'Min': [],
    'Max': [],
}

for i in outlier_indices:
    image = mild[i]
    outlier_stats['Mean'].append(np.mean(image))
    outlier_stats['Std Dev'].append(np.std(image))
    outlier_stats['Min'].append(np.min(image))
    outlier_stats['Max'].append(np.max(image))

for i in non_outlier_indices:
    image = mild[i]
    non_outlier_stats['Mean'].append(np.mean(image))
    non_outlier_stats['Std Dev'].append(np.std(image))
    non_outlier_stats['Min'].append(np.min(image))
    non_outlier_stats['Max'].append(np.max(image))

# Create subplots to visualize statistics
plt.figure(figsize=(12, 6))

stat_labels = list(outlier_stats.keys())
num_stats = len(stat_labels)

for i, stat_label in enumerate(stat_labels):
    plt.subplot(1, num_stats, i + 1)
    plt.boxplot([outlier_stats[stat_label], non_outlier_stats[stat_label]], labels=['Outliers', 'Non-Outliers'])
    plt.title(stat_label)
    plt.ylabel(stat_label)

plt.tight_layout()
plt.show()

# %% [markdown]
# The spread of the mean and standard deviation is higher for the outliers. A couple smaller max values for the outliers.

# %% [markdown]
# ---

# %% [markdown]
# ## Data preparation (cont.)

# %%
normalized_flattened_images.shape
# Out:
# (896, 49152)

# %%
flattened_images.shape
# Out:
# (896, 49152)

# %% [markdown]
# Applying the data preparation to the rest of the images

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# Assuming you have healthy, very_mild, mild, and moderate arrays

# Concatenate the arrays
all_images = np.concatenate((healthy, very_mild, mild, moderate))

# Reshape the combined array to have the shape (total_samples, num_features)
n_samples = all_images.shape[0]
num_features = np.prod(all_images.shape[1:])
flattened_images = all_images.reshape(n_samples, num_features)

# Manual normalisation. Possible to use the scaler() function, however, the outliers must be explored further. 
normalized_flattened_images = (flattened_images - np.min(flattened_images)) / (np.max(flattened_images) - np.min(flattened_images))

# Now normalized_flattened_images is a single array containing all normalized and flattened images

# %%
all_images.shape
# Out:
# (6400, 128, 128, 3)

# %%
plt.imshow(all_images[0])

# %%
normalized_flattened_images.shape
# Out:
# (6400, 49152)

# %%
# Reshape the flattened image to its original shape
plt.imshow(normalized_flattened_images[0].reshape(128, 128, 3))

# %% [markdown]
# ## 1D vector of labels

# %%
def globFn(demented_type: str):
    #stores the file names in a list
    fitsFileNames = glob.glob(data_path + demented_type +'/*.jpg') # Where the asterisk symbol acts as a wildcard
    return fitsFileNames

# %%
#creating the labels
mild_filenames = globFn('Mild_Demented')
very_mild_filenames = globFn('Very_Mild_Demented')
moderate_filenames = globFn('Moderate_Demented')
healthy_filenames = globFn('Non_Demented')

#we want to now binarize these labels so that we can use them in our `trainTestSplitFn`
mild_filenames[0:10]
# Out:
# ['./dataset/Mild_Demented\\mild.jpg',
#  './dataset/Mild_Demented\\mild_10.jpg',
#  './dataset/Mild_Demented\\mild_100.jpg',
#  './dataset/Mild_Demented\\mild_101.jpg',
#  './dataset/Mild_Demented\\mild_102.jpg',
#  './dataset/Mild_Demented\\mild_103.jpg',
#  './dataset/Mild_Demented\\mild_104.jpg',
#  './dataset/Mild_Demented\\mild_105.jpg',
#  './dataset/Mild_Demented\\mild_106.jpg',
#  './dataset/Mild_Demented\\mild_107.jpg']

# %%
len(mild_filenames)
# Out:
# 896

# %%
demented_type
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']

# %%
type_arrays = [mild, very_mild, moderate, healthy]

# Count the number of images in each category and print the counts
for i, demented_type in enumerate(demented_type):
    count = len(type_arrays[i])
    print(f"Number of images in {demented_type}: {count}")
# Out:
# Number of images in Mild_Demented: 896
# Number of images in Moderate_Demented: 2240
# Number of images in Non_Demented: 64
# Number of images in Very_Mild_Demented: 3200

# %%
all_filenames = np.concatenate((mild_filenames, very_mild_filenames, 
                                moderate_filenames, healthy_filenames))
all_filenames.shape
# Out:
# (6400,)

# %%
all_filenames
# Out:
# array(['./dataset/Mild_Demented\\mild.jpg',
#        './dataset/Mild_Demented\\mild_10.jpg',
#        './dataset/Mild_Demented\\mild_100.jpg', ...,
#        './dataset/Non_Demented\\non_997.jpg',
#        './dataset/Non_Demented\\non_998.jpg',
#        './dataset/Non_Demented\\non_999.jpg'], dtype='<U46')

# %%
mild_filenames
very_mild_filenames
moderate_filenames
healthy_filenames
# Out:
# ['./dataset/Non_Demented\\non.jpg',
#  './dataset/Non_Demented\\non_10.jpg',
#  './dataset/Non_Demented\\non_100.jpg',
#  './dataset/Non_Demented\\non_1000.jpg',
#  './dataset/Non_Demented\\non_1001.jpg',
#  './dataset/Non_Demented\\non_1002.jpg',
#  './dataset/Non_Demented\\non_1003.jpg',
#  './dataset/Non_Demented\\non_1004.jpg',
#  './dataset/Non_Demented\\non_1005.jpg',
#  './dataset/Non_Demented\\non_1006.jpg',
#  './dataset/Non_Demented\\non_1007.jpg',
#  './dataset/Non_Demented\\non_1008.jpg',
#  './dataset/Non_Demented\\non_1009.jpg',
#  './dataset/Non_Demented\\non_101.jpg',
#  './dataset/Non_Demented\\non_1010.jpg',
#  './dataset/Non_Demented\\non_1011.jpg',
#  './dataset/Non_Demented\\non_1012.jpg',
#  './dataset/Non_Demented\\non_1013.jpg',
#  './dataset/Non_Demented\\non_1014.jpg',
#  './dataset/Non_Demented\\non_1015.jpg',
#  './dataset/Non_Demented\\non_1016.jpg',
#  './dataset/Non_Demented\\non_1017.jpg',
#  './dataset/Non_Demented\\non_1018.jpg',
#  './dataset/Non_Demented\\non_1019.jpg',
#  './dataset/Non_Demented\\non_102.jpg',
#  './dataset/Non_Demented\\non_1020.jpg',
#  './dataset/Non_Demented\\non_1021.jpg',
#  './dataset/Non_Demented\\non_1022.jpg',
#  './dataset/Non_Demented\\non_1023.jpg',
#  './dataset/Non_Demented\\non_1024.jpg',
#  './dataset/Non_Demented\\non_1025.jpg',
#  './dataset/Non_Demented\\non_1026.jpg',
#  './dataset/Non_Demented\\non_1027.jpg',
#  './dataset/Non_Demented\\non_1028.jpg',
#  './dataset/Non_Demented\\non_1029.jpg',
#  './dataset/Non_Demented\\non_103.jpg',
#  './dataset/Non_Demented\\non_1030.jpg',
#  './dataset/Non_Demented\\non_1031.jpg',
#  './dataset/Non_Demented\\non_1032.jpg',
#  './dataset/Non_Demented\\non_1033.jpg',
#  './dataset/Non_Demented\\non_1034.jpg',
#  './dataset/Non_Demented\\non_1035.jpg',
#  './dataset/Non_Demented\\non_1036.jpg',
#  './dataset/Non_Demented\\non_1037.jpg',
#  './dataset/Non_Demented\\non_1038.jpg',
#  './dataset/Non_Demented\\non_1039.jpg',
#  './dataset/Non_Demented\\non_104.jpg',
#  './dataset/Non_Demented\\non_1040.jpg',
#  './dataset/Non_Demented\\non_1041.jpg',
#  './dataset/Non_Demented\\non_1042.jpg',
#  './dataset/Non_Demented\\non_1043.jpg',
#  './dataset/Non_Demented\\non_1044.jpg',
#  './dataset/Non_Demented\\non_1045.jpg',
#  './dataset/Non_Demented\\non_1046.jpg',
#  './dataset/Non_Demented\\non_1047.jpg',
#  './dataset/Non_Demented\\non_1048.jpg',
#  './dataset/Non_Demented\\non_1049.jpg',
#  './dataset/Non_Demented\\non_105.jpg',
#  './dataset/Non_Demented\\non_1050.jpg',
#  './dataset/Non_Demented\\non_1051.jpg',
#  './dataset/Non_Demented\\non_1052.jpg',
#  './dataset/Non_Demented\\non_1053.jpg',
#  './dataset/Non_Demented\\non_1054.jpg',
#  './dataset/Non_Demented\\non_1055.jpg',
#  './dataset/Non_Demented\\non_1056.jpg',
#  './dataset/Non_Demented\\non_1057.jpg',
#  './dataset/Non_Demented\\non_1058.jpg',
#  './dataset/Non_Demented\\non_1059.jpg',
#  './dataset/Non_Demented\\non_106.jpg',
#  './dataset/Non_Demented\\non_1060.jpg',
#  './dataset/Non_Demented\\non_1061.jpg',
#  './dataset/Non_Demented\\non_1062.jpg',
#  './dataset/Non_Demented\\non_1063.jpg',
#  './dataset/Non_Demented\\non_1064.jpg',
#  './dataset/Non_Demented\\non_1065.jpg',
#  './dataset/Non_Demented\\non_1066.jpg',
#  './dataset/Non_Demented\\non_1067.jpg',
#  './dataset/Non_Demented\\non_1068.jpg',
#  './dataset/Non_Demented\\non_1069.jpg',
#  './dataset/Non_Demented\\non_107.jpg',
#  './dataset/Non_Demented\\non_1070.jpg',
#  './dataset/Non_Demented\\non_1071.jpg',
#  './dataset/Non_Demented\\non_1072.jpg',
#  './dataset/Non_Demented\\non_1073.jpg',
#  './dataset/Non_Demented\\non_1074.jpg',
#  './dataset/Non_Demented\\non_1075.jpg',
#  './dataset/Non_Demented\\non_1076.jpg',
#  './dataset/Non_Demented\\non_1077.jpg',
#  './dataset/Non_Demented\\non_1078.jpg',
#  './dataset/Non_Demented\\non_1079.jpg',
#  './dataset/Non_Demented\\non_108.jpg',
#  './dataset/Non_Demented\\non_1080.jpg',
#  './dataset/Non_Demented\\non_1081.jpg',
#  './dataset/Non_Demented\\non_1082.jpg',
#  './dataset/Non_Demented\\non_1083.jpg',
#  './dataset/Non_Demented\\non_1084.jpg',
#  './dataset/Non_Demented\\non_1085.jpg',
#  './dataset/Non_Demented\\non_1086.jpg',
#  './dataset/Non_Demented\\non_1087.jpg',
#  './dataset/Non_Demented\\non_1088.jpg',
#  './dataset/Non_Demented\\non_1089.jpg',
#  './dataset/Non_Demented\\non_109.jpg',
#  './dataset/Non_Demented\\non_1090.jpg',
#  './dataset/Non_Demented\\non_1091.jpg',
#  './dataset/Non_Demented\\non_1092.jpg',
#  './dataset/Non_Demented\\non_1093.jpg',
#  './dataset/Non_Demented\\non_1094.jpg',
#  './dataset/Non_Demented\\non_1095.jpg',
#  './dataset/Non_Demented\\non_1096.jpg',
#  './dataset/Non_Demented\\non_1097.jpg',
#  './dataset/Non_Demented\\non_1098.jpg',
#  './dataset/Non_Demented\\non_1099.jpg',
#  './dataset/Non_Demented\\non_11.jpg',
#  './dataset/Non_Demented\\non_110.jpg',
#  './dataset/Non_Demented\\non_1100.jpg',
#  './dataset/Non_Demented\\non_1101.jpg',
#  './dataset/Non_Demented\\non_1102.jpg',
#  './dataset/Non_Demented\\non_1103.jpg',
#  './dataset/Non_Demented\\non_1104.jpg',
#  './dataset/Non_Demented\\non_1105.jpg',
#  './dataset/Non_Demented\\non_1106.jpg',
#  './dataset/Non_Demented\\non_1107.jpg',
#  './dataset/Non_Demented\\non_1108.jpg',
#  './dataset/Non_Demented\\non_1109.jpg',
#  './dataset/Non_Demented\\non_111.jpg',
#  './dataset/Non_Demented\\non_1110.jpg',
#  './dataset/Non_Demented\\non_1111.jpg',
#  './dataset/Non_Demented\\non_1112.jpg',
#  './dataset/Non_Demented\\non_1113.jpg',
#  './dataset/Non_Demented\\non_1114.jpg',
#  './dataset/Non_Demented\\non_1115.jpg',
#  './dataset/Non_Demented\\non_1116.jpg',
#  './dataset/Non_Demented\\non_1117.jpg',
#  './dataset/Non_Demented\\non_1118.jpg',
#  './dataset/Non_Demented\\non_1119.jpg',
#  './dataset/Non_Demented\\non_112.jpg',
#  './dataset/Non_Demented\\non_1120.jpg',
#  './dataset/Non_Demented\\non_1121.jpg',
#  './dataset/Non_Demented\\non_1122.jpg',
#  './dataset/Non_Demented\\non_1123.jpg',
#  './dataset/Non_Demented\\non_1124.jpg',
#  './dataset/Non_Demented\\non_1125.jpg',
#  './dataset/Non_Demented\\non_1126.jpg',
#  './dataset/Non_Demented\\non_1127.jpg',
#  './dataset/Non_Demented\\non_1128.jpg',
#  './dataset/Non_Demented\\non_1129.jpg',
#  './dataset/Non_Demented\\non_113.jpg',
#  './dataset/Non_Demented\\non_1130.jpg',
#  './dataset/Non_Demented\\non_1131.jpg',
#  './dataset/Non_Demented\\non_1132.jpg',
#  './dataset/Non_Demented\\non_1133.jpg',
#  './dataset/Non_Demented\\non_1134.jpg',
#  './dataset/Non_Demented\\non_1135.jpg',
#  './dataset/Non_Demented\\non_1136.jpg',
#  './dataset/Non_Demented\\non_1137.jpg',
#  './dataset/Non_Demented\\non_1138.jpg',
#  './dataset/Non_Demented\\non_1139.jpg',
#  './dataset/Non_Demented\\non_114.jpg',
#  './dataset/Non_Demented\\non_1140.jpg',
#  './dataset/Non_Demented\\non_1141.jpg',
#  './dataset/Non_Demented\\non_1142.jpg',
#  './dataset/Non_Demented\\non_1143.jpg',
#  './dataset/Non_Demented\\non_1144.jpg',
#  './dataset/Non_Demented\\non_1145.jpg',
#  './dataset/Non_Demented\\non_1146.jpg',
#  './dataset/Non_Demented\\non_1147.jpg',
#  './dataset/Non_Demented\\non_1148.jpg',
#  './dataset/Non_Demented\\non_1149.jpg',
#  './dataset/Non_Demented\\non_115.jpg',
#  './dataset/Non_Demented\\non_1150.jpg',
#  './dataset/Non_Demented\\non_1151.jpg',
#  './dataset/Non_Demented\\non_1152.jpg',
#  './dataset/Non_Demented\\non_1153.jpg',
#  './dataset/Non_Demented\\non_1154.jpg',
#  './dataset/Non_Demented\\non_1155.jpg',
#  './dataset/Non_Demented\\non_1156.jpg',
#  './dataset/Non_Demented\\non_1157.jpg',
#  './dataset/Non_Demented\\non_1158.jpg',
#  './dataset/Non_Demented\\non_1159.jpg',
#  './dataset/Non_Demented\\non_116.jpg',
#  './dataset/Non_Demented\\non_1160.jpg',
#  './dataset/Non_Demented\\non_1161.jpg',
#  './dataset/Non_Demented\\non_1162.jpg',
#  './dataset/Non_Demented\\non_1163.jpg',
#  './dataset/Non_Demented\\non_1164.jpg',
#  './dataset/Non_Demented\\non_1165.jpg',
#  './dataset/Non_Demented\\non_1166.jpg',
#  './dataset/Non_Demented\\non_1167.jpg',
#  './dataset/Non_Demented\\non_1168.jpg',
#  './dataset/Non_Demented\\non_1169.jpg',
#  './dataset/Non_Demented\\non_117.jpg',
#  './dataset/Non_Demented\\non_1170.jpg',
#  './dataset/Non_Demented\\non_1171.jpg',
#  './dataset/Non_Demented\\non_1172.jpg',
#  './dataset/Non_Demented\\non_1173.jpg',
#  './dataset/Non_Demented\\non_1174.jpg',
#  './dataset/Non_Demented\\non_1175.jpg',
#  './dataset/Non_Demented\\non_1176.jpg',
#  './dataset/Non_Demented\\non_1177.jpg',
#  './dataset/Non_Demented\\non_1178.jpg',
#  './dataset/Non_Demented\\non_1179.jpg',
#  './dataset/Non_Demented\\non_118.jpg',
#  './dataset/Non_Demented\\non_1180.jpg',
#  './dataset/Non_Demented\\non_1181.jpg',
#  './dataset/Non_Demented\\non_1182.jpg',
#  './dataset/Non_Demented\\non_1183.jpg',
#  './dataset/Non_Demented\\non_1184.jpg',
#  './dataset/Non_Demented\\non_1185.jpg',
#  './dataset/Non_Demented\\non_1186.jpg',
#  './dataset/Non_Demented\\non_1187.jpg',
#  './dataset/Non_Demented\\non_1188.jpg',
#  './dataset/Non_Demented\\non_1189.jpg',
#  './dataset/Non_Demented\\non_119.jpg',
#  './dataset/Non_Demented\\non_1190.jpg',
#  './dataset/Non_Demented\\non_1191.jpg',
#  './dataset/Non_Demented\\non_1192.jpg',
#  './dataset/Non_Demented\\non_1193.jpg',
#  './dataset/Non_Demented\\non_1194.jpg',
#  './dataset/Non_Demented\\non_1195.jpg',
#  './dataset/Non_Demented\\non_1196.jpg',
#  './dataset/Non_Demented\\non_1197.jpg',
#  './dataset/Non_Demented\\non_1198.jpg',
#  './dataset/Non_Demented\\non_1199.jpg',
#  './dataset/Non_Demented\\non_12.jpg',
#  './dataset/Non_Demented\\non_120.jpg',
#  './dataset/Non_Demented\\non_1200.jpg',
#  './dataset/Non_Demented\\non_1201.jpg',
#  './dataset/Non_Demented\\non_1202.jpg',
#  './dataset/Non_Demented\\non_1203.jpg',
#  './dataset/Non_Demented\\non_1204.jpg',
#  './dataset/Non_Demented\\non_1205.jpg',
#  './dataset/Non_Demented\\non_1206.jpg',
#  './dataset/Non_Demented\\non_1207.jpg',
#  './dataset/Non_Demented\\non_1208.jpg',
#  './dataset/Non_Demented\\non_1209.jpg',
#  './dataset/Non_Demented\\non_121.jpg',
#  './dataset/Non_Demented\\non_1210.jpg',
#  './dataset/Non_Demented\\non_1211.jpg',
#  './dataset/Non_Demented\\non_1212.jpg',
#  './dataset/Non_Demented\\non_1213.jpg',
#  './dataset/Non_Demented\\non_1214.jpg',
#  './dataset/Non_Demented\\non_1215.jpg',
#  './dataset/Non_Demented\\non_1216.jpg',
#  './dataset/Non_Demented\\non_1217.jpg',
#  './dataset/Non_Demented\\non_1218.jpg',
#  './dataset/Non_Demented\\non_1219.jpg',
#  './dataset/Non_Demented\\non_122.jpg',
#  './dataset/Non_Demented\\non_1220.jpg',
#  './dataset/Non_Demented\\non_1221.jpg',
#  './dataset/Non_Demented\\non_1222.jpg',
#  './dataset/Non_Demented\\non_1223.jpg',
#  './dataset/Non_Demented\\non_1224.jpg',
#  './dataset/Non_Demented\\non_1225.jpg',
#  './dataset/Non_Demented\\non_1226.jpg',
#  './dataset/Non_Demented\\non_1227.jpg',
#  './dataset/Non_Demented\\non_1228.jpg',
#  './dataset/Non_Demented\\non_1229.jpg',
#  './dataset/Non_Demented\\non_123.jpg',
#  './dataset/Non_Demented\\non_1230.jpg',
#  './dataset/Non_Demented\\non_1231.jpg',
#  './dataset/Non_Demented\\non_1232.jpg',
#  './dataset/Non_Demented\\non_1233.jpg',
#  './dataset/Non_Demented\\non_1234.jpg',
#  './dataset/Non_Demented\\non_1235.jpg',
#  './dataset/Non_Demented\\non_1236.jpg',
#  './dataset/Non_Demented\\non_1237.jpg',
#  './dataset/Non_Demented\\non_1238.jpg',
#  './dataset/Non_Demented\\non_1239.jpg',
#  './dataset/Non_Demented\\non_124.jpg',
#  './dataset/Non_Demented\\non_1240.jpg',
#  './dataset/Non_Demented\\non_1241.jpg',
#  './dataset/Non_Demented\\non_1242.jpg',
#  './dataset/Non_Demented\\non_1243.jpg',
#  './dataset/Non_Demented\\non_1244.jpg',
#  './dataset/Non_Demented\\non_1245.jpg',
#  './dataset/Non_Demented\\non_1246.jpg',
#  './dataset/Non_Demented\\non_1247.jpg',
#  './dataset/Non_Demented\\non_1248.jpg',
#  './dataset/Non_Demented\\non_1249.jpg',
#  './dataset/Non_Demented\\non_125.jpg',
#  './dataset/Non_Demented\\non_1250.jpg',
#  './dataset/Non_Demented\\non_1251.jpg',
#  './dataset/Non_Demented\\non_1252.jpg',
#  './dataset/Non_Demented\\non_1253.jpg',
#  './dataset/Non_Demented\\non_1254.jpg',
#  './dataset/Non_Demented\\non_1255.jpg',
#  './dataset/Non_Demented\\non_1256.jpg',
#  './dataset/Non_Demented\\non_1257.jpg',
#  './dataset/Non_Demented\\non_1258.jpg',
#  './dataset/Non_Demented\\non_1259.jpg',
#  './dataset/Non_Demented\\non_126.jpg',
#  './dataset/Non_Demented\\non_1260.jpg',
#  './dataset/Non_Demented\\non_1261.jpg',
#  './dataset/Non_Demented\\non_1262.jpg',
#  './dataset/Non_Demented\\non_1263.jpg',
#  './dataset/Non_Demented\\non_1264.jpg',
#  './dataset/Non_Demented\\non_1265.jpg',
#  './dataset/Non_Demented\\non_1266.jpg',
#  './dataset/Non_Demented\\non_1267.jpg',
#  './dataset/Non_Demented\\non_1268.jpg',
#  './dataset/Non_Demented\\non_1269.jpg',
#  './dataset/Non_Demented\\non_127.jpg',
#  './dataset/Non_Demented\\non_1270.jpg',
#  './dataset/Non_Demented\\non_1271.jpg',
#  './dataset/Non_Demented\\non_1272.jpg',
#  './dataset/Non_Demented\\non_1273.jpg',
#  './dataset/Non_Demented\\non_1274.jpg',
#  './dataset/Non_Demented\\non_1275.jpg',
#  './dataset/Non_Demented\\non_1276.jpg',
#  './dataset/Non_Demented\\non_1277.jpg',
#  './dataset/Non_Demented\\non_1278.jpg',
#  './dataset/Non_Demented\\non_1279.jpg',
#  './dataset/Non_Demented\\non_128.jpg',
#  './dataset/Non_Demented\\non_1280.jpg',
#  './dataset/Non_Demented\\non_1281.jpg',
#  './dataset/Non_Demented\\non_1282.jpg',
#  './dataset/Non_Demented\\non_1283.jpg',
#  './dataset/Non_Demented\\non_1284.jpg',
#  './dataset/Non_Demented\\non_1285.jpg',
#  './dataset/Non_Demented\\non_1286.jpg',
#  './dataset/Non_Demented\\non_1287.jpg',
#  './dataset/Non_Demented\\non_1288.jpg',
#  './dataset/Non_Demented\\non_1289.jpg',
#  './dataset/Non_Demented\\non_129.jpg',
#  './dataset/Non_Demented\\non_1290.jpg',
#  './dataset/Non_Demented\\non_1291.jpg',
#  './dataset/Non_Demented\\non_1292.jpg',
#  './dataset/Non_Demented\\non_1293.jpg',
#  './dataset/Non_Demented\\non_1294.jpg',
#  './dataset/Non_Demented\\non_1295.jpg',
#  './dataset/Non_Demented\\non_1296.jpg',
#  './dataset/Non_Demented\\non_1297.jpg',
#  './dataset/Non_Demented\\non_1298.jpg',
#  './dataset/Non_Demented\\non_1299.jpg',
#  './dataset/Non_Demented\\non_13.jpg',
#  './dataset/Non_Demented\\non_130.jpg',
#  './dataset/Non_Demented\\non_1300.jpg',
#  './dataset/Non_Demented\\non_1301.jpg',
#  './dataset/Non_Demented\\non_1302.jpg',
#  './dataset/Non_Demented\\non_1303.jpg',
#  './dataset/Non_Demented\\non_1304.jpg',
#  './dataset/Non_Demented\\non_1305.jpg',
#  './dataset/Non_Demented\\non_1306.jpg',
#  './dataset/Non_Demented\\non_1307.jpg',
#  './dataset/Non_Demented\\non_1308.jpg',
#  './dataset/Non_Demented\\non_1309.jpg',
#  './dataset/Non_Demented\\non_131.jpg',
#  './dataset/Non_Demented\\non_1310.jpg',
#  './dataset/Non_Demented\\non_1311.jpg',
#  './dataset/Non_Demented\\non_1312.jpg',
#  './dataset/Non_Demented\\non_1313.jpg',
#  './dataset/Non_Demented\\non_1314.jpg',
#  './dataset/Non_Demented\\non_1315.jpg',
#  './dataset/Non_Demented\\non_1316.jpg',
#  './dataset/Non_Demented\\non_1317.jpg',
#  './dataset/Non_Demented\\non_1318.jpg',
#  './dataset/Non_Demented\\non_1319.jpg',
#  './dataset/Non_Demented\\non_132.jpg',
#  './dataset/Non_Demented\\non_1320.jpg',
#  './dataset/Non_Demented\\non_1321.jpg',
#  './dataset/Non_Demented\\non_1322.jpg',
#  './dataset/Non_Demented\\non_1323.jpg',
#  './dataset/Non_Demented\\non_1324.jpg',
#  './dataset/Non_Demented\\non_1325.jpg',
#  './dataset/Non_Demented\\non_1326.jpg',
#  './dataset/Non_Demented\\non_1327.jpg',
#  './dataset/Non_Demented\\non_1328.jpg',
#  './dataset/Non_Demented\\non_1329.jpg',
#  './dataset/Non_Demented\\non_133.jpg',
#  './dataset/Non_Demented\\non_1330.jpg',
#  './dataset/Non_Demented\\non_1331.jpg',
#  './dataset/Non_Demented\\non_1332.jpg',
#  './dataset/Non_Demented\\non_1333.jpg',
#  './dataset/Non_Demented\\non_1334.jpg',
#  './dataset/Non_Demented\\non_1335.jpg',
#  './dataset/Non_Demented\\non_1336.jpg',
#  './dataset/Non_Demented\\non_1337.jpg',
#  './dataset/Non_Demented\\non_1338.jpg',
#  './dataset/Non_Demented\\non_1339.jpg',
#  './dataset/Non_Demented\\non_134.jpg',
#  './dataset/Non_Demented\\non_1340.jpg',
#  './dataset/Non_Demented\\non_1341.jpg',
#  './dataset/Non_Demented\\non_1342.jpg',
#  './dataset/Non_Demented\\non_1343.jpg',
#  './dataset/Non_Demented\\non_1344.jpg',
#  './dataset/Non_Demented\\non_1345.jpg',
#  './dataset/Non_Demented\\non_1346.jpg',
#  './dataset/Non_Demented\\non_1347.jpg',
#  './dataset/Non_Demented\\non_1348.jpg',
#  './dataset/Non_Demented\\non_1349.jpg',
#  './dataset/Non_Demented\\non_135.jpg',
#  './dataset/Non_Demented\\non_1350.jpg',
#  './dataset/Non_Demented\\non_1351.jpg',
#  './dataset/Non_Demented\\non_1352.jpg',
#  './dataset/Non_Demented\\non_1353.jpg',
#  './dataset/Non_Demented\\non_1354.jpg',
#  './dataset/Non_Demented\\non_1355.jpg',
#  './dataset/Non_Demented\\non_1356.jpg',
#  './dataset/Non_Demented\\non_1357.jpg',
#  './dataset/Non_Demented\\non_1358.jpg',
#  './dataset/Non_Demented\\non_1359.jpg',
#  './dataset/Non_Demented\\non_136.jpg',
#  './dataset/Non_Demented\\non_1360.jpg',
#  './dataset/Non_Demented\\non_1361.jpg',
#  './dataset/Non_Demented\\non_1362.jpg',
#  './dataset/Non_Demented\\non_1363.jpg',
#  './dataset/Non_Demented\\non_1364.jpg',
#  './dataset/Non_Demented\\non_1365.jpg',
#  './dataset/Non_Demented\\non_1366.jpg',
#  './dataset/Non_Demented\\non_1367.jpg',
#  './dataset/Non_Demented\\non_1368.jpg',
#  './dataset/Non_Demented\\non_1369.jpg',
#  './dataset/Non_Demented\\non_137.jpg',
#  './dataset/Non_Demented\\non_1370.jpg',
#  './dataset/Non_Demented\\non_1371.jpg',
#  './dataset/Non_Demented\\non_1372.jpg',
#  './dataset/Non_Demented\\non_1373.jpg',
#  './dataset/Non_Demented\\non_1374.jpg',
#  './dataset/Non_Demented\\non_1375.jpg',
#  './dataset/Non_Demented\\non_1376.jpg',
#  './dataset/Non_Demented\\non_1377.jpg',
#  './dataset/Non_Demented\\non_1378.jpg',
#  './dataset/Non_Demented\\non_1379.jpg',
#  './dataset/Non_Demented\\non_138.jpg',
#  './dataset/Non_Demented\\non_1380.jpg',
#  './dataset/Non_Demented\\non_1381.jpg',
#  './dataset/Non_Demented\\non_1382.jpg',
#  './dataset/Non_Demented\\non_1383.jpg',
#  './dataset/Non_Demented\\non_1384.jpg',
#  './dataset/Non_Demented\\non_1385.jpg',
#  './dataset/Non_Demented\\non_1386.jpg',
#  './dataset/Non_Demented\\non_1387.jpg',
#  './dataset/Non_Demented\\non_1388.jpg',
#  './dataset/Non_Demented\\non_1389.jpg',
#  './dataset/Non_Demented\\non_139.jpg',
#  './dataset/Non_Demented\\non_1390.jpg',
#  './dataset/Non_Demented\\non_1391.jpg',
#  './dataset/Non_Demented\\non_1392.jpg',
#  './dataset/Non_Demented\\non_1393.jpg',
#  './dataset/Non_Demented\\non_1394.jpg',
#  './dataset/Non_Demented\\non_1395.jpg',
#  './dataset/Non_Demented\\non_1396.jpg',
#  './dataset/Non_Demented\\non_1397.jpg',
#  './dataset/Non_Demented\\non_1398.jpg',
#  './dataset/Non_Demented\\non_1399.jpg',
#  './dataset/Non_Demented\\non_14.jpg',
#  './dataset/Non_Demented\\non_140.jpg',
#  './dataset/Non_Demented\\non_1400.jpg',
#  './dataset/Non_Demented\\non_1401.jpg',
#  './dataset/Non_Demented\\non_1402.jpg',
#  './dataset/Non_Demented\\non_1403.jpg',
#  './dataset/Non_Demented\\non_1404.jpg',
#  './dataset/Non_Demented\\non_1405.jpg',
#  './dataset/Non_Demented\\non_1406.jpg',
#  './dataset/Non_Demented\\non_1407.jpg',
#  './dataset/Non_Demented\\non_1408.jpg',
#  './dataset/Non_Demented\\non_1409.jpg',
#  './dataset/Non_Demented\\non_141.jpg',
#  './dataset/Non_Demented\\non_1410.jpg',
#  './dataset/Non_Demented\\non_1411.jpg',
#  './dataset/Non_Demented\\non_1412.jpg',
#  './dataset/Non_Demented\\non_1413.jpg',
#  './dataset/Non_Demented\\non_1414.jpg',
#  './dataset/Non_Demented\\non_1415.jpg',
#  './dataset/Non_Demented\\non_1416.jpg',
#  './dataset/Non_Demented\\non_1417.jpg',
#  './dataset/Non_Demented\\non_1418.jpg',
#  './dataset/Non_Demented\\non_1419.jpg',
#  './dataset/Non_Demented\\non_142.jpg',
#  './dataset/Non_Demented\\non_1420.jpg',
#  './dataset/Non_Demented\\non_1421.jpg',
#  './dataset/Non_Demented\\non_1422.jpg',
#  './dataset/Non_Demented\\non_1423.jpg',
#  './dataset/Non_Demented\\non_1424.jpg',
#  './dataset/Non_Demented\\non_1425.jpg',
#  './dataset/Non_Demented\\non_1426.jpg',
#  './dataset/Non_Demented\\non_1427.jpg',
#  './dataset/Non_Demented\\non_1428.jpg',
#  './dataset/Non_Demented\\non_1429.jpg',
#  './dataset/Non_Demented\\non_143.jpg',
#  './dataset/Non_Demented\\non_1430.jpg',
#  './dataset/Non_Demented\\non_1431.jpg',
#  './dataset/Non_Demented\\non_1432.jpg',
#  './dataset/Non_Demented\\non_1433.jpg',
#  './dataset/Non_Demented\\non_1434.jpg',
#  './dataset/Non_Demented\\non_1435.jpg',
#  './dataset/Non_Demented\\non_1436.jpg',
#  './dataset/Non_Demented\\non_1437.jpg',
#  './dataset/Non_Demented\\non_1438.jpg',
#  './dataset/Non_Demented\\non_1439.jpg',
#  './dataset/Non_Demented\\non_144.jpg',
#  './dataset/Non_Demented\\non_1440.jpg',
#  './dataset/Non_Demented\\non_1441.jpg',
#  './dataset/Non_Demented\\non_1442.jpg',
#  './dataset/Non_Demented\\non_1443.jpg',
#  './dataset/Non_Demented\\non_1444.jpg',
#  './dataset/Non_Demented\\non_1445.jpg',
#  './dataset/Non_Demented\\non_1446.jpg',
#  './dataset/Non_Demented\\non_1447.jpg',
#  './dataset/Non_Demented\\non_1448.jpg',
#  './dataset/Non_Demented\\non_1449.jpg',
#  './dataset/Non_Demented\\non_145.jpg',
#  './dataset/Non_Demented\\non_1450.jpg',
#  './dataset/Non_Demented\\non_1451.jpg',
#  './dataset/Non_Demented\\non_1452.jpg',
#  './dataset/Non_Demented\\non_1453.jpg',
#  './dataset/Non_Demented\\non_1454.jpg',
#  './dataset/Non_Demented\\non_1455.jpg',
#  './dataset/Non_Demented\\non_1456.jpg',
#  './dataset/Non_Demented\\non_1457.jpg',
#  './dataset/Non_Demented\\non_1458.jpg',
#  './dataset/Non_Demented\\non_1459.jpg',
#  './dataset/Non_Demented\\non_146.jpg',
#  './dataset/Non_Demented\\non_1460.jpg',
#  './dataset/Non_Demented\\non_1461.jpg',
#  './dataset/Non_Demented\\non_1462.jpg',
#  './dataset/Non_Demented\\non_1463.jpg',
#  './dataset/Non_Demented\\non_1464.jpg',
#  './dataset/Non_Demented\\non_1465.jpg',
#  './dataset/Non_Demented\\non_1466.jpg',
#  './dataset/Non_Demented\\non_1467.jpg',
#  './dataset/Non_Demented\\non_1468.jpg',
#  './dataset/Non_Demented\\non_1469.jpg',
#  './dataset/Non_Demented\\non_147.jpg',
#  './dataset/Non_Demented\\non_1470.jpg',
#  './dataset/Non_Demented\\non_1471.jpg',
#  './dataset/Non_Demented\\non_1472.jpg',
#  './dataset/Non_Demented\\non_1473.jpg',
#  './dataset/Non_Demented\\non_1474.jpg',
#  './dataset/Non_Demented\\non_1475.jpg',
#  './dataset/Non_Demented\\non_1476.jpg',
#  './dataset/Non_Demented\\non_1477.jpg',
#  './dataset/Non_Demented\\non_1478.jpg',
#  './dataset/Non_Demented\\non_1479.jpg',
#  './dataset/Non_Demented\\non_148.jpg',
#  './dataset/Non_Demented\\non_1480.jpg',
#  './dataset/Non_Demented\\non_1481.jpg',
#  './dataset/Non_Demented\\non_1482.jpg',
#  './dataset/Non_Demented\\non_1483.jpg',
#  './dataset/Non_Demented\\non_1484.jpg',
#  './dataset/Non_Demented\\non_1485.jpg',
#  './dataset/Non_Demented\\non_1486.jpg',
#  './dataset/Non_Demented\\non_1487.jpg',
#  './dataset/Non_Demented\\non_1488.jpg',
#  './dataset/Non_Demented\\non_1489.jpg',
#  './dataset/Non_Demented\\non_149.jpg',
#  './dataset/Non_Demented\\non_1490.jpg',
#  './dataset/Non_Demented\\non_1491.jpg',
#  './dataset/Non_Demented\\non_1492.jpg',
#  './dataset/Non_Demented\\non_1493.jpg',
#  './dataset/Non_Demented\\non_1494.jpg',
#  './dataset/Non_Demented\\non_1495.jpg',
#  './dataset/Non_Demented\\non_1496.jpg',
#  './dataset/Non_Demented\\non_1497.jpg',
#  './dataset/Non_Demented\\non_1498.jpg',
#  './dataset/Non_Demented\\non_1499.jpg',
#  './dataset/Non_Demented\\non_15.jpg',
#  './dataset/Non_Demented\\non_150.jpg',
#  './dataset/Non_Demented\\non_1500.jpg',
#  './dataset/Non_Demented\\non_1501.jpg',
#  './dataset/Non_Demented\\non_1502.jpg',
#  './dataset/Non_Demented\\non_1503.jpg',
#  './dataset/Non_Demented\\non_1504.jpg',
#  './dataset/Non_Demented\\non_1505.jpg',
#  './dataset/Non_Demented\\non_1506.jpg',
#  './dataset/Non_Demented\\non_1507.jpg',
#  './dataset/Non_Demented\\non_1508.jpg',
#  './dataset/Non_Demented\\non_1509.jpg',
#  './dataset/Non_Demented\\non_151.jpg',
#  './dataset/Non_Demented\\non_1510.jpg',
#  './dataset/Non_Demented\\non_1511.jpg',
#  './dataset/Non_Demented\\non_1512.jpg',
#  './dataset/Non_Demented\\non_1513.jpg',
#  './dataset/Non_Demented\\non_1514.jpg',
#  './dataset/Non_Demented\\non_1515.jpg',
#  './dataset/Non_Demented\\non_1516.jpg',
#  './dataset/Non_Demented\\non_1517.jpg',
#  './dataset/Non_Demented\\non_1518.jpg',
#  './dataset/Non_Demented\\non_1519.jpg',
#  './dataset/Non_Demented\\non_152.jpg',
#  './dataset/Non_Demented\\non_1520.jpg',
#  './dataset/Non_Demented\\non_1521.jpg',
#  './dataset/Non_Demented\\non_1522.jpg',
#  './dataset/Non_Demented\\non_1523.jpg',
#  './dataset/Non_Demented\\non_1524.jpg',
#  './dataset/Non_Demented\\non_1525.jpg',
#  './dataset/Non_Demented\\non_1526.jpg',
#  './dataset/Non_Demented\\non_1527.jpg',
#  './dataset/Non_Demented\\non_1528.jpg',
#  './dataset/Non_Demented\\non_1529.jpg',
#  './dataset/Non_Demented\\non_153.jpg',
#  './dataset/Non_Demented\\non_1530.jpg',
#  './dataset/Non_Demented\\non_1531.jpg',
#  './dataset/Non_Demented\\non_1532.jpg',
#  './dataset/Non_Demented\\non_1533.jpg',
#  './dataset/Non_Demented\\non_1534.jpg',
#  './dataset/Non_Demented\\non_1535.jpg',
#  './dataset/Non_Demented\\non_1536.jpg',
#  './dataset/Non_Demented\\non_1537.jpg',
#  './dataset/Non_Demented\\non_1538.jpg',
#  './dataset/Non_Demented\\non_1539.jpg',
#  './dataset/Non_Demented\\non_154.jpg',
#  './dataset/Non_Demented\\non_1540.jpg',
#  './dataset/Non_Demented\\non_1541.jpg',
#  './dataset/Non_Demented\\non_1542.jpg',
#  './dataset/Non_Demented\\non_1543.jpg',
#  './dataset/Non_Demented\\non_1544.jpg',
#  './dataset/Non_Demented\\non_1545.jpg',
#  './dataset/Non_Demented\\non_1546.jpg',
#  './dataset/Non_Demented\\non_1547.jpg',
#  './dataset/Non_Demented\\non_1548.jpg',
#  './dataset/Non_Demented\\non_1549.jpg',
#  './dataset/Non_Demented\\non_155.jpg',
#  './dataset/Non_Demented\\non_1550.jpg',
#  './dataset/Non_Demented\\non_1551.jpg',
#  './dataset/Non_Demented\\non_1552.jpg',
#  './dataset/Non_Demented\\non_1553.jpg',
#  './dataset/Non_Demented\\non_1554.jpg',
#  './dataset/Non_Demented\\non_1555.jpg',
#  './dataset/Non_Demented\\non_1556.jpg',
#  './dataset/Non_Demented\\non_1557.jpg',
#  './dataset/Non_Demented\\non_1558.jpg',
#  './dataset/Non_Demented\\non_1559.jpg',
#  './dataset/Non_Demented\\non_156.jpg',
#  './dataset/Non_Demented\\non_1560.jpg',
#  './dataset/Non_Demented\\non_1561.jpg',
#  './dataset/Non_Demented\\non_1562.jpg',
#  './dataset/Non_Demented\\non_1563.jpg',
#  './dataset/Non_Demented\\non_1564.jpg',
#  './dataset/Non_Demented\\non_1565.jpg',
#  './dataset/Non_Demented\\non_1566.jpg',
#  './dataset/Non_Demented\\non_1567.jpg',
#  './dataset/Non_Demented\\non_1568.jpg',
#  './dataset/Non_Demented\\non_1569.jpg',
#  './dataset/Non_Demented\\non_157.jpg',
#  './dataset/Non_Demented\\non_1570.jpg',
#  './dataset/Non_Demented\\non_1571.jpg',
#  './dataset/Non_Demented\\non_1572.jpg',
#  './dataset/Non_Demented\\non_1573.jpg',
#  './dataset/Non_Demented\\non_1574.jpg',
#  './dataset/Non_Demented\\non_1575.jpg',
#  './dataset/Non_Demented\\non_1576.jpg',
#  './dataset/Non_Demented\\non_1577.jpg',
#  './dataset/Non_Demented\\non_1578.jpg',
#  './dataset/Non_Demented\\non_1579.jpg',
#  './dataset/Non_Demented\\non_158.jpg',
#  './dataset/Non_Demented\\non_1580.jpg',
#  './dataset/Non_Demented\\non_1581.jpg',
#  './dataset/Non_Demented\\non_1582.jpg',
#  './dataset/Non_Demented\\non_1583.jpg',
#  './dataset/Non_Demented\\non_1584.jpg',
#  './dataset/Non_Demented\\non_1585.jpg',
#  './dataset/Non_Demented\\non_1586.jpg',
#  './dataset/Non_Demented\\non_1587.jpg',
#  './dataset/Non_Demented\\non_1588.jpg',
#  './dataset/Non_Demented\\non_1589.jpg',
#  './dataset/Non_Demented\\non_159.jpg',
#  './dataset/Non_Demented\\non_1590.jpg',
#  './dataset/Non_Demented\\non_1591.jpg',
#  './dataset/Non_Demented\\non_1592.jpg',
#  './dataset/Non_Demented\\non_1593.jpg',
#  './dataset/Non_Demented\\non_1594.jpg',
#  './dataset/Non_Demented\\non_1595.jpg',
#  './dataset/Non_Demented\\non_1596.jpg',
#  './dataset/Non_Demented\\non_1597.jpg',
#  './dataset/Non_Demented\\non_1598.jpg',
#  './dataset/Non_Demented\\non_1599.jpg',
#  './dataset/Non_Demented\\non_16.jpg',
#  './dataset/Non_Demented\\non_160.jpg',
#  './dataset/Non_Demented\\non_1600.jpg',
#  './dataset/Non_Demented\\non_1601.jpg',
#  './dataset/Non_Demented\\non_1602.jpg',
#  './dataset/Non_Demented\\non_1603.jpg',
#  './dataset/Non_Demented\\non_1604.jpg',
#  './dataset/Non_Demented\\non_1605.jpg',
#  './dataset/Non_Demented\\non_1606.jpg',
#  './dataset/Non_Demented\\non_1607.jpg',
#  './dataset/Non_Demented\\non_1608.jpg',
#  './dataset/Non_Demented\\non_1609.jpg',
#  './dataset/Non_Demented\\non_161.jpg',
#  './dataset/Non_Demented\\non_1610.jpg',
#  './dataset/Non_Demented\\non_1611.jpg',
#  './dataset/Non_Demented\\non_1612.jpg',
#  './dataset/Non_Demented\\non_1613.jpg',
#  './dataset/Non_Demented\\non_1614.jpg',
#  './dataset/Non_Demented\\non_1615.jpg',
#  './dataset/Non_Demented\\non_1616.jpg',
#  './dataset/Non_Demented\\non_1617.jpg',
#  './dataset/Non_Demented\\non_1618.jpg',
#  './dataset/Non_Demented\\non_1619.jpg',
#  './dataset/Non_Demented\\non_162.jpg',
#  './dataset/Non_Demented\\non_1620.jpg',
#  './dataset/Non_Demented\\non_1621.jpg',
#  './dataset/Non_Demented\\non_1622.jpg',
#  './dataset/Non_Demented\\non_1623.jpg',
#  './dataset/Non_Demented\\non_1624.jpg',
#  './dataset/Non_Demented\\non_1625.jpg',
#  './dataset/Non_Demented\\non_1626.jpg',
#  './dataset/Non_Demented\\non_1627.jpg',
#  './dataset/Non_Demented\\non_1628.jpg',
#  './dataset/Non_Demented\\non_1629.jpg',
#  './dataset/Non_Demented\\non_163.jpg',
#  './dataset/Non_Demented\\non_1630.jpg',
#  './dataset/Non_Demented\\non_1631.jpg',
#  './dataset/Non_Demented\\non_1632.jpg',
#  './dataset/Non_Demented\\non_1633.jpg',
#  './dataset/Non_Demented\\non_1634.jpg',
#  './dataset/Non_Demented\\non_1635.jpg',
#  './dataset/Non_Demented\\non_1636.jpg',
#  './dataset/Non_Demented\\non_1637.jpg',
#  './dataset/Non_Demented\\non_1638.jpg',
#  './dataset/Non_Demented\\non_1639.jpg',
#  './dataset/Non_Demented\\non_164.jpg',
#  './dataset/Non_Demented\\non_1640.jpg',
#  './dataset/Non_Demented\\non_1641.jpg',
#  './dataset/Non_Demented\\non_1642.jpg',
#  './dataset/Non_Demented\\non_1643.jpg',
#  './dataset/Non_Demented\\non_1644.jpg',
#  './dataset/Non_Demented\\non_1645.jpg',
#  './dataset/Non_Demented\\non_1646.jpg',
#  './dataset/Non_Demented\\non_1647.jpg',
#  './dataset/Non_Demented\\non_1648.jpg',
#  './dataset/Non_Demented\\non_1649.jpg',
#  './dataset/Non_Demented\\non_165.jpg',
#  './dataset/Non_Demented\\non_1650.jpg',
#  './dataset/Non_Demented\\non_1651.jpg',
#  './dataset/Non_Demented\\non_1652.jpg',
#  './dataset/Non_Demented\\non_1653.jpg',
#  './dataset/Non_Demented\\non_1654.jpg',
#  './dataset/Non_Demented\\non_1655.jpg',
#  './dataset/Non_Demented\\non_1656.jpg',
#  './dataset/Non_Demented\\non_1657.jpg',
#  './dataset/Non_Demented\\non_1658.jpg',
#  './dataset/Non_Demented\\non_1659.jpg',
#  './dataset/Non_Demented\\non_166.jpg',
#  './dataset/Non_Demented\\non_1660.jpg',
#  './dataset/Non_Demented\\non_1661.jpg',
#  './dataset/Non_Demented\\non_1662.jpg',
#  './dataset/Non_Demented\\non_1663.jpg',
#  './dataset/Non_Demented\\non_1664.jpg',
#  './dataset/Non_Demented\\non_1665.jpg',
#  './dataset/Non_Demented\\non_1666.jpg',
#  './dataset/Non_Demented\\non_1667.jpg',
#  './dataset/Non_Demented\\non_1668.jpg',
#  './dataset/Non_Demented\\non_1669.jpg',
#  './dataset/Non_Demented\\non_167.jpg',
#  './dataset/Non_Demented\\non_1670.jpg',
#  './dataset/Non_Demented\\non_1671.jpg',
#  './dataset/Non_Demented\\non_1672.jpg',
#  './dataset/Non_Demented\\non_1673.jpg',
#  './dataset/Non_Demented\\non_1674.jpg',
#  './dataset/Non_Demented\\non_1675.jpg',
#  './dataset/Non_Demented\\non_1676.jpg',
#  './dataset/Non_Demented\\non_1677.jpg',
#  './dataset/Non_Demented\\non_1678.jpg',
#  './dataset/Non_Demented\\non_1679.jpg',
#  './dataset/Non_Demented\\non_168.jpg',
#  './dataset/Non_Demented\\non_1680.jpg',
#  './dataset/Non_Demented\\non_1681.jpg',
#  './dataset/Non_Demented\\non_1682.jpg',
#  './dataset/Non_Demented\\non_1683.jpg',
#  './dataset/Non_Demented\\non_1684.jpg',
#  './dataset/Non_Demented\\non_1685.jpg',
#  './dataset/Non_Demented\\non_1686.jpg',
#  './dataset/Non_Demented\\non_1687.jpg',
#  './dataset/Non_Demented\\non_1688.jpg',
#  './dataset/Non_Demented\\non_1689.jpg',
#  './dataset/Non_Demented\\non_169.jpg',
#  './dataset/Non_Demented\\non_1690.jpg',
#  './dataset/Non_Demented\\non_1691.jpg',
#  './dataset/Non_Demented\\non_1692.jpg',
#  './dataset/Non_Demented\\non_1693.jpg',
#  './dataset/Non_Demented\\non_1694.jpg',
#  './dataset/Non_Demented\\non_1695.jpg',
#  './dataset/Non_Demented\\non_1696.jpg',
#  './dataset/Non_Demented\\non_1697.jpg',
#  './dataset/Non_Demented\\non_1698.jpg',
#  './dataset/Non_Demented\\non_1699.jpg',
#  './dataset/Non_Demented\\non_17.jpg',
#  './dataset/Non_Demented\\non_170.jpg',
#  './dataset/Non_Demented\\non_1700.jpg',
#  './dataset/Non_Demented\\non_1701.jpg',
#  './dataset/Non_Demented\\non_1702.jpg',
#  './dataset/Non_Demented\\non_1703.jpg',
#  './dataset/Non_Demented\\non_1704.jpg',
#  './dataset/Non_Demented\\non_1705.jpg',
#  './dataset/Non_Demented\\non_1706.jpg',
#  './dataset/Non_Demented\\non_1707.jpg',
#  './dataset/Non_Demented\\non_1708.jpg',
#  './dataset/Non_Demented\\non_1709.jpg',
#  './dataset/Non_Demented\\non_171.jpg',
#  './dataset/Non_Demented\\non_1710.jpg',
#  './dataset/Non_Demented\\non_1711.jpg',
#  './dataset/Non_Demented\\non_1712.jpg',
#  './dataset/Non_Demented\\non_1713.jpg',
#  './dataset/Non_Demented\\non_1714.jpg',
#  './dataset/Non_Demented\\non_1715.jpg',
#  './dataset/Non_Demented\\non_1716.jpg',
#  './dataset/Non_Demented\\non_1717.jpg',
#  './dataset/Non_Demented\\non_1718.jpg',
#  './dataset/Non_Demented\\non_1719.jpg',
#  './dataset/Non_Demented\\non_172.jpg',
#  './dataset/Non_Demented\\non_1720.jpg',
#  './dataset/Non_Demented\\non_1721.jpg',
#  './dataset/Non_Demented\\non_1722.jpg',
#  './dataset/Non_Demented\\non_1723.jpg',
#  './dataset/Non_Demented\\non_1724.jpg',
#  './dataset/Non_Demented\\non_1725.jpg',
#  './dataset/Non_Demented\\non_1726.jpg',
#  './dataset/Non_Demented\\non_1727.jpg',
#  './dataset/Non_Demented\\non_1728.jpg',
#  './dataset/Non_Demented\\non_1729.jpg',
#  './dataset/Non_Demented\\non_173.jpg',
#  './dataset/Non_Demented\\non_1730.jpg',
#  './dataset/Non_Demented\\non_1731.jpg',
#  './dataset/Non_Demented\\non_1732.jpg',
#  './dataset/Non_Demented\\non_1733.jpg',
#  './dataset/Non_Demented\\non_1734.jpg',
#  './dataset/Non_Demented\\non_1735.jpg',
#  './dataset/Non_Demented\\non_1736.jpg',
#  './dataset/Non_Demented\\non_1737.jpg',
#  './dataset/Non_Demented\\non_1738.jpg',
#  './dataset/Non_Demented\\non_1739.jpg',
#  './dataset/Non_Demented\\non_174.jpg',
#  './dataset/Non_Demented\\non_1740.jpg',
#  './dataset/Non_Demented\\non_1741.jpg',
#  './dataset/Non_Demented\\non_1742.jpg',
#  './dataset/Non_Demented\\non_1743.jpg',
#  './dataset/Non_Demented\\non_1744.jpg',
#  './dataset/Non_Demented\\non_1745.jpg',
#  './dataset/Non_Demented\\non_1746.jpg',
#  './dataset/Non_Demented\\non_1747.jpg',
#  './dataset/Non_Demented\\non_1748.jpg',
#  './dataset/Non_Demented\\non_1749.jpg',
#  './dataset/Non_Demented\\non_175.jpg',
#  './dataset/Non_Demented\\non_1750.jpg',
#  './dataset/Non_Demented\\non_1751.jpg',
#  './dataset/Non_Demented\\non_1752.jpg',
#  './dataset/Non_Demented\\non_1753.jpg',
#  './dataset/Non_Demented\\non_1754.jpg',
#  './dataset/Non_Demented\\non_1755.jpg',
#  './dataset/Non_Demented\\non_1756.jpg',
#  './dataset/Non_Demented\\non_1757.jpg',
#  './dataset/Non_Demented\\non_1758.jpg',
#  './dataset/Non_Demented\\non_1759.jpg',
#  './dataset/Non_Demented\\non_176.jpg',
#  './dataset/Non_Demented\\non_1760.jpg',
#  './dataset/Non_Demented\\non_1761.jpg',
#  './dataset/Non_Demented\\non_1762.jpg',
#  './dataset/Non_Demented\\non_1763.jpg',
#  './dataset/Non_Demented\\non_1764.jpg',
#  './dataset/Non_Demented\\non_1765.jpg',
#  './dataset/Non_Demented\\non_1766.jpg',
#  './dataset/Non_Demented\\non_1767.jpg',
#  './dataset/Non_Demented\\non_1768.jpg',
#  './dataset/Non_Demented\\non_1769.jpg',
#  './dataset/Non_Demented\\non_177.jpg',
#  './dataset/Non_Demented\\non_1770.jpg',
#  './dataset/Non_Demented\\non_1771.jpg',
#  './dataset/Non_Demented\\non_1772.jpg',
#  './dataset/Non_Demented\\non_1773.jpg',
#  './dataset/Non_Demented\\non_1774.jpg',
#  './dataset/Non_Demented\\non_1775.jpg',
#  './dataset/Non_Demented\\non_1776.jpg',
#  './dataset/Non_Demented\\non_1777.jpg',
#  './dataset/Non_Demented\\non_1778.jpg',
#  './dataset/Non_Demented\\non_1779.jpg',
#  './dataset/Non_Demented\\non_178.jpg',
#  './dataset/Non_Demented\\non_1780.jpg',
#  './dataset/Non_Demented\\non_1781.jpg',
#  './dataset/Non_Demented\\non_1782.jpg',
#  './dataset/Non_Demented\\non_1783.jpg',
#  './dataset/Non_Demented\\non_1784.jpg',
#  './dataset/Non_Demented\\non_1785.jpg',
#  './dataset/Non_Demented\\non_1786.jpg',
#  './dataset/Non_Demented\\non_1787.jpg',
#  './dataset/Non_Demented\\non_1788.jpg',
#  './dataset/Non_Demented\\non_1789.jpg',
#  './dataset/Non_Demented\\non_179.jpg',
#  './dataset/Non_Demented\\non_1790.jpg',
#  './dataset/Non_Demented\\non_1791.jpg',
#  './dataset/Non_Demented\\non_1792.jpg',
#  './dataset/Non_Demented\\non_1793.jpg',
#  './dataset/Non_Demented\\non_1794.jpg',
#  './dataset/Non_Demented\\non_1795.jpg',
#  './dataset/Non_Demented\\non_1796.jpg',
#  './dataset/Non_Demented\\non_1797.jpg',
#  './dataset/Non_Demented\\non_1798.jpg',
#  './dataset/Non_Demented\\non_1799.jpg',
#  './dataset/Non_Demented\\non_18.jpg',
#  './dataset/Non_Demented\\non_180.jpg',
#  './dataset/Non_Demented\\non_1800.jpg',
#  './dataset/Non_Demented\\non_1801.jpg',
#  './dataset/Non_Demented\\non_1802.jpg',
#  './dataset/Non_Demented\\non_1803.jpg',
#  './dataset/Non_Demented\\non_1804.jpg',
#  './dataset/Non_Demented\\non_1805.jpg',
#  './dataset/Non_Demented\\non_1806.jpg',
#  './dataset/Non_Demented\\non_1807.jpg',
#  './dataset/Non_Demented\\non_1808.jpg',
#  './dataset/Non_Demented\\non_1809.jpg',
#  './dataset/Non_Demented\\non_181.jpg',
#  './dataset/Non_Demented\\non_1810.jpg',
#  './dataset/Non_Demented\\non_1811.jpg',
#  './dataset/Non_Demented\\non_1812.jpg',
#  './dataset/Non_Demented\\non_1813.jpg',
#  './dataset/Non_Demented\\non_1814.jpg',
#  './dataset/Non_Demented\\non_1815.jpg',
#  './dataset/Non_Demented\\non_1816.jpg',
#  './dataset/Non_Demented\\non_1817.jpg',
#  './dataset/Non_Demented\\non_1818.jpg',
#  './dataset/Non_Demented\\non_1819.jpg',
#  './dataset/Non_Demented\\non_182.jpg',
#  './dataset/Non_Demented\\non_1820.jpg',
#  './dataset/Non_Demented\\non_1821.jpg',
#  './dataset/Non_Demented\\non_1822.jpg',
#  './dataset/Non_Demented\\non_1823.jpg',
#  './dataset/Non_Demented\\non_1824.jpg',
#  './dataset/Non_Demented\\non_1825.jpg',
#  './dataset/Non_Demented\\non_1826.jpg',
#  './dataset/Non_Demented\\non_1827.jpg',
#  './dataset/Non_Demented\\non_1828.jpg',
#  './dataset/Non_Demented\\non_1829.jpg',
#  './dataset/Non_Demented\\non_183.jpg',
#  './dataset/Non_Demented\\non_1830.jpg',
#  './dataset/Non_Demented\\non_1831.jpg',
#  './dataset/Non_Demented\\non_1832.jpg',
#  './dataset/Non_Demented\\non_1833.jpg',
#  './dataset/Non_Demented\\non_1834.jpg',
#  './dataset/Non_Demented\\non_1835.jpg',
#  './dataset/Non_Demented\\non_1836.jpg',
#  './dataset/Non_Demented\\non_1837.jpg',
#  './dataset/Non_Demented\\non_1838.jpg',
#  './dataset/Non_Demented\\non_1839.jpg',
#  './dataset/Non_Demented\\non_184.jpg',
#  './dataset/Non_Demented\\non_1840.jpg',
#  './dataset/Non_Demented\\non_1841.jpg',
#  './dataset/Non_Demented\\non_1842.jpg',
#  './dataset/Non_Demented\\non_1843.jpg',
#  './dataset/Non_Demented\\non_1844.jpg',
#  './dataset/Non_Demented\\non_1845.jpg',
#  './dataset/Non_Demented\\non_1846.jpg',
#  './dataset/Non_Demented\\non_1847.jpg',
#  './dataset/Non_Demented\\non_1848.jpg',
#  './dataset/Non_Demented\\non_1849.jpg',
#  './dataset/Non_Demented\\non_185.jpg',
#  './dataset/Non_Demented\\non_1850.jpg',
#  './dataset/Non_Demented\\non_1851.jpg',
#  './dataset/Non_Demented\\non_1852.jpg',
#  './dataset/Non_Demented\\non_1853.jpg',
#  './dataset/Non_Demented\\non_1854.jpg',
#  './dataset/Non_Demented\\non_1855.jpg',
#  './dataset/Non_Demented\\non_1856.jpg',
#  './dataset/Non_Demented\\non_1857.jpg',
#  './dataset/Non_Demented\\non_1858.jpg',
#  './dataset/Non_Demented\\non_1859.jpg',
#  './dataset/Non_Demented\\non_186.jpg',
#  './dataset/Non_Demented\\non_1860.jpg',
#  './dataset/Non_Demented\\non_1861.jpg',
#  './dataset/Non_Demented\\non_1862.jpg',
#  './dataset/Non_Demented\\non_1863.jpg',
#  './dataset/Non_Demented\\non_1864.jpg',
#  './dataset/Non_Demented\\non_1865.jpg',
#  './dataset/Non_Demented\\non_1866.jpg',
#  './dataset/Non_Demented\\non_1867.jpg',
#  './dataset/Non_Demented\\non_1868.jpg',
#  './dataset/Non_Demented\\non_1869.jpg',
#  './dataset/Non_Demented\\non_187.jpg',
#  './dataset/Non_Demented\\non_1870.jpg',
#  './dataset/Non_Demented\\non_1871.jpg',
#  './dataset/Non_Demented\\non_1872.jpg',
#  './dataset/Non_Demented\\non_1873.jpg',
#  './dataset/Non_Demented\\non_1874.jpg',
#  './dataset/Non_Demented\\non_1875.jpg',
#  './dataset/Non_Demented\\non_1876.jpg',
#  './dataset/Non_Demented\\non_1877.jpg',
#  './dataset/Non_Demented\\non_1878.jpg',
#  './dataset/Non_Demented\\non_1879.jpg',
#  './dataset/Non_Demented\\non_188.jpg',
#  './dataset/Non_Demented\\non_1880.jpg',
#  './dataset/Non_Demented\\non_1881.jpg',
#  './dataset/Non_Demented\\non_1882.jpg',
#  './dataset/Non_Demented\\non_1883.jpg',
#  './dataset/Non_Demented\\non_1884.jpg',
#  './dataset/Non_Demented\\non_1885.jpg',
#  './dataset/Non_Demented\\non_1886.jpg',
#  './dataset/Non_Demented\\non_1887.jpg',
#  './dataset/Non_Demented\\non_1888.jpg',
#  './dataset/Non_Demented\\non_1889.jpg',
#  './dataset/Non_Demented\\non_189.jpg',
#  './dataset/Non_Demented\\non_1890.jpg',
#  './dataset/Non_Demented\\non_1891.jpg',
#  './dataset/Non_Demented\\non_1892.jpg',
#  './dataset/Non_Demented\\non_1893.jpg',
#  './dataset/Non_Demented\\non_1894.jpg',
#  './dataset/Non_Demented\\non_1895.jpg',
#  './dataset/Non_Demented\\non_1896.jpg',
#  './dataset/Non_Demented\\non_1897.jpg',
#  './dataset/Non_Demented\\non_1898.jpg',
#  './dataset/Non_Demented\\non_1899.jpg',
#  ...]

# %%
labels = []

for filename in mild_filenames:
    labels.append(0)

for filename in very_mild_filenames:
    labels.append(1)

for filename in moderate_filenames:
    labels.append(2)

for filename in healthy_filenames:
    labels.append(3)

labels = np.array(labels)
print(labels.shape)
# Out:
# (6400,)

# %% [markdown]
# # Model training

# %%
from sklearn.model_selection import train_test_split

#splitting the DF with the split function
train_set, test_set, train_labels, test_labels= train_test_split(normalized_flattened_images, labels, stratify= labels, test_size= 0.3, random_state= 42)

# %%
train_set.shape
# Out:
# (4480, 49152)

# %%
test_set.shape
# Out:
# (1920, 49152)

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer() #sets the function to a variable, less writing.

#converting our labels which contain 0,1,2 into one-hot vector format which is required for the binarizor function
train_labels = lb.fit_transform(train_labels)
test_labels = lb.transform(test_labels) 

print('train_labels shape: ', train_labels.shape, 'and test_labels shape: ', test_labels.shape)
# Out:
# train_labels shape:  (4480, 4) and test_labels shape:  (1920, 4)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Create an MLP (Multi-Layer Perceptron) model
model = MLPClassifier(
    hidden_layer_sizes=(256, 128),
    activation="logistic",  # Use "logistic" for sigmoid activation
    max_iter=100,
    learning_rate_init=0.01,
    momentum=0.9,
    random_state=42  # Set random_state for reproducibility
)

# Fit the model to your training data
model.fit(train_set, train_labels)

# Predict on the test data
predictions_ann = model.predict(test_set)

# Generate a classification report to evaluate the model
print(classification_report(test_labels, predictions_ann))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       269
#            1       0.00      0.00      0.00       672
#            2       0.00      0.00      0.00        19
#            3       0.50      1.00      0.67       960
#
#    micro avg       0.50      0.50      0.50      1920
#    macro avg       0.12      0.25      0.17      1920
# weighted avg       0.25      0.50      0.33      1920
#  samples avg       0.50      0.50      0.50      1920
# C:\Users\Rudol\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# To modify the code so that the number of images for each type of dementia is similar, you can perform either oversampling of the minority class ("Non_Demented") or undersampling of the majority class ("Moderate_Demented"). Here, I'll show how to perform oversampling to balance the classes using the imbalanced-learn library, assuming you have a dataset imbalance where "Non_Demented" has fewer samples:

# %%
pip install imbalanced-learn
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade --force-reinstall scikit-learn
# Out:
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Rudol\\AppData\\Local\\Temp\\pip-uninstall-fxgi4boh\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# Requirement already satisfied: imbalanced-learn in c:\users\rudol\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\rudol\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\rudol\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\rudol\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\rudol\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rudol\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Collecting numpy>=1.17.3
#   Using cached numpy-1.22.4-cp38-cp38-win_amd64.whl (14.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler

# Assuming you have imported your data into train_set, train_labels, test_set, and test_labels

# Create a RandomOverSampler
oversampler = RandomOverSampler(random_state=42)

# Fit and transform the training data to balance the classes
train_set_resampled, train_labels_resampled = oversampler.fit_resample(train_set, train_labels)

# Create an MLP (Multi-Layer Perceptron) model
model = MLPClassifier(
    hidden_layer_sizes=(256, 128),
    activation="logistic",  # Use "logistic" for sigmoid activation
    max_iter=100,
    learning_rate_init=0.01,
    momentum=0.9,
    random_state=42  # Set random_state for reproducibility
)

# Fit the model to your resampled training data
model.fit(train_set_resampled, train_labels_resampled)

# Predict on the test data
predictions_ann = model.predict(test_set)

# Generate a classification report to evaluate the model
print(classification_report(test_labels, predictions_ann))
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Collecting numpy<2.0,>=1.17.3
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
# Collecting scipy>=1.5.0
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Installing collected packages: numpy, threadpoolctl, scipy, joblib, scikit-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.1
#     Uninstalling scipy-1.7.1:
#       Successfully uninstalled scipy-1.7.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Rudol\\AppData\\Local\\Temp\\pip-uninstall-js2kxomq\\msvcp140.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (c:\users\rudol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\rudol\anaconda3\lib\site-packages)
# C:\Users\Rudol\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       269
#            1       0.00      0.00      0.00       672
#            2       0.00      0.00      0.00        19
#            3       0.00      0.00      0.00       960
#
#    micro avg       0.00      0.00      0.00      1920
#    macro avg       0.00      0.00      0.00      1920
# weighted avg       0.00      0.00      0.00      1920
#  samples avg       0.00      0.00      0.00      1920
# C:\Users\Rudol\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Rudol\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Rudol\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Convert EagerTensor to a NumPy array
test_labels

# Print a formatted report
print(classification_report(
    test_labels.argmax(axis=1), 
    predictionsANN.argmax(axis=1), 
    target_names=[str(x) for x in lb.classes_]
))

# %%
# Convert EagerTensor to a NumPy array
test_labels

# Print a formatted report
print(classification_report(
    test_labels.argmax(axis=1), 
    predictionsANN.argmax(axis=1), 
    target_names=[str(x) for x in lb.classes_]
))

# %%
from sklearn.metrics import classification_report


# Create a list of class names in the order of the indices
target_names = [demented_type_dict[i] for i in range(len(demented_type_dict))]

# Print a formatted report
print(classification_report(
    test_labels_np.argmax(axis=1), 
    predictionsANN.argmax(axis=1), 
    target_names=target_names
))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Extract predicted labels from the model's predictions
predictions = np.argmax(predictionsANN, axis=1)

# Extract true labels from the test_labels
true_labels = np.argmax(test_labels, axis=1)

class_names = [demented_type_dict[0], demented_type_dict[1],
               demented_type_dict[2], demented_type_dict[3]]  # Replace with your class names

# Create the confusion matrix
conf_matrix = confusion_matrix(true_labels, predictions)

# Create a heatmap-style confusion matrix visualization
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %% [markdown]
# moderate has low precision due to low number of available images. We can check if adding weights to this class will improve the results.
#
# very_mild and mild have some flase predictions understandably due to the similarities. We see the same behaviour between healthy and very_mild, even less with mild.

# %%
# Compute the confusion matrix
confusion = confusion_matrix(
    test_labels.argmax(axis=1),
    predictionsANN.argmax(axis=1),
    normalize='true'  # Set normalize to 'true' for proportions
)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, cmap='Blues', fmt='.2f',
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalized Confusion Matrix')
plt.show()

# %% [markdown]
# ## Additional performance visualisations and metrics

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), H.history['loss'], label='Training Loss')
plt.plot(range(1, epochs + 1), H.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), H.history['accuracy'], label='Training Accuracy')
plt.plot(range(1, epochs + 1), H.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(test_labels[:, 1], predictionsANN[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, _ = precision_recall_curve(test_labels[:, 1], predictionsANN[:, 1])

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid()
plt.show()

# %% [markdown]
# ## Adding weights to a class

# %% [markdown]
# Adding weights to the moderate class due to low number of images

# %%
from sklearn.utils.class_weight import compute_class_weight

# Flatten the train_labels array
train_labels_flat = train_labels.flatten()

# Compute class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels_flat), y=train_labels_flat)
class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

# %%
classes

# %%
class_weights_dict

# %% [markdown]
# Flattening the `train_labels` causes information loss about each individual class. Better to use the labels before one-hot encoding and before splitting the dataset.

# %%
from sklearn.utils.class_weight import compute_class_weight

# Assuming 'images' contains the image data and 'labels' contains the original labels

# Convert original labels to one-hot encoded format
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# Compute class weights
class_weights = compute_class_weight('balanced', classes=np.unique(labels_encoded), y=labels_encoded)
class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

# %%
class_weights_dictr

# %%
train_set, test_set, train_labels, test_labels= train_test_split(normalized_flattened_images, labels, 
                                                                 stratify= labels, test_size= 0.3, random_state= 42)

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer() #sets the function to a variable, less writing.

#converting our labels which contain 0,1,2 into one-hot vector format which is required for the binarizor function
train_labels = lb.fit_transform(train_labels)
test_labels = lb.transform(test_labels) 

print('train_labels shape: ', train_labels.shape, 'and test_labels shape: ', test_labels.shape)

# %%
# Create a Sequential model
model = Sequential()

# Add layers to the model
model.add(Dense(256, input_shape=(49152,), activation="sigmoid"))
model.add(Dense(128, activation="sigmoid"))
model.add(Dense(4, activation="softmax"))

# Define optimizer
learnRate = 0.01
opt = SGD(learning_rate=learnRate, momentum=0.9)

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

# Number of runs the model does
epochs = 100


# Applying the data to the model with class weights
H = model.fit(train_set, train_labels, validation_data=(test_set, test_labels),
              epochs=epochs, batch_size=64, verbose=1, class_weight=class_weights_dict)

# Applying the model to all the test data to check how well it's performed
predictionsANN = model.predict(test_set)

# %%
# Print a formatted report
print(classification_report(
    test_labels_np.argmax(axis=1), 
    predictionsANN.argmax(axis=1), 
    target_names=target_names
))

# %%
# Compute the confusion matrix
confusion = confusion_matrix(
    test_labels.argmax(axis=1),
    predictionsANN.argmax(axis=1),
    normalize='true'  # Set normalize to 'true' for proportions
)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, cmap='Blues', fmt='.2f',
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalized Confusion Matrix')
plt.show()

# %% [markdown]
# Similar performance, performed better in other places compared to the model without class weights. With the number of images in the `moderate` class, it may be more wise to perform data augmentation followed by weights to see how the model improves.

# %% [markdown]
# # Hyperparameter tweaking

# %%
# Create a Sequential model
model = Sequential()

# Add layers to the model
model.add(Dense(256, input_shape=(49152,), activation="sigmoid"))
model.add(Dense(128, activation="sigmoid"))
model.add(Dense(4, activation="softmax"))

# Define optimizer
learnRate = 0.01
opt = SGD(learning_rate=learnRate, momentum=0.9)

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

# Number of runs the model does
epochs = 100

# Applying the data to the model
H = model.fit(train_set, train_labels, validation_data=(test_set, test_labels),
          epochs=epochs, batch_size=64, verbose=1)

# Applying the model to all the test data to check how well it's performed
predictionsANN = model.predict(test_set)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import classification_report

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt


# Define your Keras Sequential model
def create_model(learn_rate=0.01):
    model = Sequential()
    model.add(Dense(256, input_shape=(49152,), activation="sigmoid"))
    model.add(Dense(128, activation="sigmoid"))
    model.add(Dense(4, activation="softmax"))
    
    opt = SGD(learning_rate=learn_rate, momentum=0.9)
    
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    return model

# Create the model
model = create_model()

# Define hyperparameters and their potential values for grid search
param_grid = {
    'learn_rate': [0.001, 0.01, 0.1],
    'epochs': [50, 100, 150],
    'batch_size': [32, 64, 128]
}

# Create GridSearchCV instance
grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1)

# Fit the grid search to your data
grid_search.fit(train_set, train_labels)  # Replace with your training data

# Get the best hyperparameters from the grid search
best_params = grid_search.best_params_

# Train a model with the best hyperparameters on the full training set
best_model = create_model(**best_params)  # Create a new model instance with best hyperparameters
best_model.fit(train_set, train_labels, epochs=best_params['epochs'], batch_size=best_params['batch_size'])

# Use the best model to make predictions
predictionsANN = best_model.predict(test_set)  # Replace with your test data

# Rest of your code for confusion matrix visualization
# ...

# # Finally, visualize the confusion matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
# plt.title("Confusion Matrix")
# plt.xlabel("Predicted Labels")
# plt.ylabel("True Labels")
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier  # Make sure to import the appropriate neural network class

# Define your neural network model
model = MLPClassifier()  # Replace with your model architecture and configuration

# Define hyperparameters and their potential values for grid search
param_grid = {
    'hidden_layer_sizes': [(100,), (200,), (100, 100)],
    'activation': ['relu', 'tanh'],
    'alpha': [0.0001, 0.001, 0.01],
}

# Create GridSearchCV instance
grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1)

# Fit the grid search to your data
grid_search.fit(X_train, y_train)  # Replace with your training data

# Get the best hyperparameters from the grid search
best_params = grid_search.best_params_

# Train a model with the best hyperparameters on the full training set
best_model = MLPClassifier(**best_params)  # Create a new model instance with best hyperparameters
best_model.fit(X_train, y_train)  # Train the model on the full training data

# Use the best model to make predictions
predictions = best_model.predict(X_test)  # Replace with your test data

# Rest of your code for confusion matrix visualization
# Compute the confusion matrix
confusion = confusion_matrix(
    test_labels.argmax(axis=1),
    predictionsANN.argmax(axis=1),
    normalize='true'  # Set normalize to 'true' for proportions
)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, cmap='Blues', fmt='.2f',
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalized Confusion Matrix')
plt.show()


# Finally, visualize the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %% [markdown]
# # Data Augmentation
